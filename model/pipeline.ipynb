# %%
from backend import Backend

back = Backend()

back.work('orig.mp4')
# Out:
# MoviePy - Writing audio in out_audio.wav
# MoviePy - Done.
# Transcribe:   0%|          | 0/2708.61 [00:00<?, ?sec/s]
# Detected language: russian
# Transcribe: 100%|█████████▉| 2708.32/2708.61 [01:29<00:00, 30.25sec/s]
# Saved: /Users/shidlovskiy/Projects/hackathons/hackathon-vseros/model/audio.tsv
# [{'start': 0.0, 'end': 4.68, 'text': 'СТУК'},
#  {'start': 5.38, 'end': 5.92, 'text': 'Да.'},
#  {'start': 6.42, 'end': 7.36, 'text': 'Это борода.'},
#  {'start': 8.02,
#   'end': 11.02,
#   'text': 'Я уже спрашивал вас в моем СИГРАМ Каналии.'},
#  {'start': 11.02,
#   'end': 13.9,
#   'text': 'Вы сказали океи, го, вот только так надо снимать.'},
#  {'start': 14.08, 'end': 14.8, 'text': 'А через просидю вас,'},
#  {'start': 14.84,
#   'end': 16.58,
#   'text': 'зрители новичевых, как вам моя борода.'},
#  {'start': 16.82, 'end': 17.84, 'text': 'Прошу вас и не ругать,'},
#  {'start': 18.26, 'end': 19.73, 'text': 'она молода, она стесняется.'},
#  {'start': 19.94,
#   'end': 23.1,
# ...
