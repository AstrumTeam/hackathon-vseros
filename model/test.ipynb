# %%
import pandas as pd

data = pd.read_csv("data.csv", delimiter=',')[4:]


for a in data['tags']:
    sec_tags = []
    tags = a.replace('-', ' ').split(' ')
    for tag in tags:
        print(tag)
        min_sec = tag.split(':')
        if len(min_sec) == 3:
            sec_tags.append(int(min_sec[0])*60*60 + int(min_sec[1])*60 + int(min_sec[2]))
        else:
            sec_tags.append(int(min_sec[0])*60 + int(min_sec[1]))
# Out:
# 0:00
# 1:10
# 1:57
# 2:27
# 8:07
# 9:04
# 10:15
# 10:49
# 12:40
# 13:13
# 16:38
# 17:22
# 19:50
# 20:34
# 22:38
# 23:25
# 30:12
# 30:56
# 34:58
# 35:25
# 39:00
# 41:15
# 44:43
# 45:13
# 49:43
# 50:16
# 51:23
# 51:54
# 53:00
# 53:28
# 56:25
# 57:13
# 58:47
# 59:21
# 1:04:37
# 1:05:11
# 1:07:08
# 1:09:16
# 1:11:06
# 1:11:38
# 1:14:26
# 1:14:59
# 1:21:03
# 1:21:36
# 0:20
# 0:50
# 5:04
# 6:08
# 17:07
# 18:07
# 38:51
# 39:28
# 46:50
# 47:27
# 1:03:12
# 1:04:26
# 1:09:16
# 1:10:05
# 1:20:29
# 1:21:15
# 1:23:01
# 1:25:00
# 1:28:32
# 1:29:28
# 1:33:50
# 1:34:32
# 1:37:32
# 1:38:08
# 1:48:35
# 1:49:12
# 0:05
# 0:45
# 5:15
# 5:43
# 8:05
# 6:00
# 13:48
# 14:19
# 22:27
# 24:18
# 32:03
# 32:44
# 34:14
# 34:49
# 37:28
# 38:03
# 45:19
# 45:51
# 48:16
# 48:45
# 54:34
# 55:02
# 58:05
# 58:33
# 1:01:30
# 1:01:54
# 1:04:58
# 1:05:46
# 1:11:36
# 1:12:00
# 1:15:14
# 1:16:45
# 0:10
# 0:42
# 7:01
# 7:26
# 9:58
# 10:17
# 13:44
# 14:33
# 15:47
# 16:20
# 20:12
# 20:50
# 22:48
# 23:40
# 25:39
# 26:07
# 27:57
# ...

# %%
dataset1 = pd.read_csv("dataset1.csv", delimiter=',')
dataset2 = pd.read_csv("dataset2.csv", delimiter=',')
dataset3 = pd.read_csv("dataset3.csv", delimiter=',')
dataset4 = pd.read_csv("dataset4.csv", delimiter=',')
dataset5 = pd.read_csv("dataset5.csv", delimiter=',')
dataset = pd.concat([dataset1, dataset2, dataset3, dataset4, dataset5]).reset_index(drop=True)
dataset.to_csv('dataset.csv', index=False)
dataset
# Out:
#                                                 Sentense  Tag
# 0                                          Здравствуйте.  1.0
# 1                                        Да, это борода.  1.0
# 2      Я уже спрашивал вас в моем телеграм-канале, вы...  1.0
# 3      Хочу спросить у вас, зрители на ютубе, как вам...  1.0
# 4      Прошу вас ее не ругать, она молода, она стесня...  1.0
# ...                                                  ...  ...
# 27136           All it took was four gallons of lava Oh!  1.0
# 27137                             Something's happening!  1.0
# 27138                                                Oh!  1.0
# 27139                                               Wow!  1.0
# 27140  Luckily we had some fire extinguishers on hand...  1.0
#
# [27141 rows x 2 columns]
