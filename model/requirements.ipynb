# %%
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install ffmpeg #так же поставить на сервер
# !pip3 install moviepy
# !pip3 install pydub
# !pip3 install --no-deps -U yt-dlp
# !pip3 install natasha
# !pip3 install opencv-python-headless 
# !pip3 install opencv-python 
# !pip3 install wheel 
# !pip3 install cmake
# !pip3 install dlib

# !pip3 install -U git+https://github.com/jianfch/stable-ts.git
# !pip3 install -U stable-ts
# !pip3 install faster-whisper
# !pip3 install -U stable-ts[fw]
# !pip3 install accelerate
# !pip3 install optimum

# !pip3 install torch torchvision torchaudio
# !pip3 install transformers
# !pip3 install -U scikit-learn
# !pip3 install -U matplotlib
# !pip3 install -U scipy
# !pip3 install fastapi uvicorn
# !pip3 install python-multipart
# Out:
# ...
#   Using cached dlib-19.24.6.tar.gz (3.4 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for dlib: filename=dlib-19.24.6-cp39-cp39-macosx_14_0_universal2.whl size=2943343 sha256=f63c50f0066c369396742624e55b89f178dc98351acc0ca73cbe7558e031d250
#   Stored in directory: /Users/shidlovskiy/Library/Caches/pip/wheels/f5/ba/ea/ad13d4a963e5dbbbaf4dce5fef93353e2e7586ba8b7787221c
# Successfully built dlib
# ...
